# %% [markdown]
# # Lesson 2: Working with vectors

# %% [markdown]
# We will use numpy arrays to represent vectors

# %%
import numpy as np

# %% [markdown]
# ## 1 ) Brief Introduction

# %% [markdown]
# A numpy array can be explicitly created by casting from a list:

# %%
x1 = np.array([2,1,5,4])
x1
# Out:
# array([2, 1, 5, 4])

# %% [markdown]
# Note the shape of this array:

# %%
x1.shape
# Out:
# (4,)

# %% [markdown]
# This is a vector of size 4.

# %% [markdown]
# Other ways to construct a vector:

# %%
x2 = np.ones(4)
x2
# Out:
# array([1., 1., 1., 1.])

# %%
x3 = np.linspace(3,10,8) # (start, end, number of points)
x3
# Out:
# array([ 3.,  4.,  5.,  6.,  7.,  8.,  9., 10.])

# %%
x4 = np.linspace(3,10,15) # (start, end, number of points)
x4
# Out:
# array([ 3. ,  3.5,  4. ,  4.5,  5. ,  5.5,  6. ,  6.5,  7. ,  7.5,  8. ,
#         8.5,  9. ,  9.5, 10. ])

# %% [markdown]
# #### Getting an element of the array
# Recall that numpy uses 0-indexing.

# %%
x4[0]
# Out:
# 3.0

# %%
x4[3]
# Out:
# 4.5

# %% [markdown]
# #### Multiply a vector by a scalar
# Note the element-wise multiplication

# %%
a = 2
x1*a
# Out:
# array([ 4,  2, 10,  8])

# %% [markdown]
# #### Summing two vectors

# %%
x1+x2
# Out:
# array([3., 2., 6., 5.])

# %% [markdown]
# #### Element-wise functions
# Numpy comes with many built-in functions that can simplify your code, these will apply some operation element-wise to a vector.

# %%
# cos(x)
np.cos(x3)
# Out:
# array([-0.9899925 , -0.65364362,  0.28366219,  0.96017029,  0.75390225,
#        -0.14550003, -0.91113026, -0.83907153])

# %%
# e^x
np.exp(x3)
# Out:
# array([2.00855369e+01, 5.45981500e+01, 1.48413159e+02, 4.03428793e+02,
#        1.09663316e+03, 2.98095799e+03, 8.10308393e+03, 2.20264658e+04])

# %%
# ln x
np.log(x3)
# Out:
# array([1.09861229, 1.38629436, 1.60943791, 1.79175947, 1.94591015,
#        2.07944154, 2.19722458, 2.30258509])

# %% [markdown]
# **Check your answers!**
#
# Now try to calculate $\tan(x3)$ **without** using `np.tan()`. (hint: $\tan \theta = \frac{\sin \theta}{\cos \theta}$).
#
# Define `x5` and store your result in it.

# %%
#grade
x5 = np.sin(x3)/np.cos(x3)

# %% [markdown]
# ## 2 ) Making plots

# %% [markdown]
# We will use `matplotlib.pyplot` to make plots. We will start with the most basic usages of it. But if you are interested, you can find more examples [here](https://matplotlib.org/gallery/index.html).
#
# `%matplotlib inline` allows the output of plotting commands to be displayed in the jupyter notebook.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We will first plot a point in $\mathbb{R}^2$ with coordinates (x,y) = (1,2)

# %%
# We will use the code snippet below to make a plot with the same aspect ratio for both axes
ax = plt.gca()
ax.set_aspect('equal')

plt.plot(1, 2, 'o')

# %% [markdown]
# We can plot more than one point by repeating the `plt.plot` line above.
#
#
# **Try this!**
#
# Add the points (2,3) and (5,2) to the code snippet below:

# %%
# We will use the code snippet below to make a plot with the same aspect ratio for both axes
ax = plt.gca()
ax.set_aspect('equal')

# To define the limits in the x and y-directions
plt.xlim(0,6)
plt.ylim(0,6)
# Adding labels to the plot
plt.xlabel('x');
plt.ylabel('y');

plt.plot(1,2,'o')

# add the points (2, 3) and (5, 2) below
plt.plot(2,3,'o')
plt.plot(5,2,'o')

# %% [markdown]
# **Try this!**
#
# Make the same plot as above using just one `plt.plot` call:
#
# ```python
# plt.plot( [x1,x2,x3], [y1,y2,y3] )
# ```
# where for example (x1,y1) are the (x,y) coordinates for the first point.

# %%
ax = plt.gca()
ax.set_aspect('equal')

# To define the limits in the x and y-directions
plt.xlim(0,6)
plt.ylim(0,6)
# Adding labels to the plot
plt.xlabel('x');
plt.ylabel('y');

# Use one line of code to plot the points (1, 2), (2, 3), and (5, 2)
plt.plot( [1,2,5], [2,3,2], "o" )

# %% [markdown]
# #### We will now use numpy arrays. A vector in $\mathbb{R}^2$: u = (x,y)

# %%
u = np.array([1,2])

# %% [markdown]
# **Try this!**
#
# Plot `u` using
# ```python
# plt.plot(x,y,'o') # 'o' specifies the point to be drawn as a circle
# ```
#
# where you can get the x coordinate from `u[0]` and the y coordinate from `u[1]`

# %%
# We will use the code snippet below to make a plot with the same aspect ratio
ax = plt.gca()
ax.set_aspect('equal')

# To define the limits in the x and y-directions
plt.xlim(0,3)
plt.ylim(0,3)
# Adding labels to the plot
plt.xlabel('x');
plt.ylabel('y');

# Plot the u
plt.plot(u[0],u[1],'o')

# %% [markdown]
# We can use the matplotlib function:
# ```python
# matplotlib.pyplot.arrow(x, y, dx, dy)
# ```
# to plot an arrow to indicate the vector with origin at `(x,y)` to the point `(x+dx, y+dy)`

# %%
# We will use the code snippet below to make a plot with the same aspect ratio
ax = plt.gca()
ax.set_aspect('equal')

# To define the limits in the x and y-directions
plt.xlim(0,3)
plt.ylim(0,3)
# Adding labels to the plot
plt.xlabel('x');
plt.ylabel('y');

# What does the 'length_includes_head' argument do?  Try setting it to False.
plt.arrow(0,0,u[0],u[1],length_includes_head=True, head_width=0.1)

# %% [markdown]
# Suppose we have the vectors:

# %%
u = np.array([2,3])
v = np.array([5,2])

# %% [markdown]
# **Check your answers!**
#
# Define the vector `z`, the sum of the vectors `u` and `v`.

# %%
#grade (enter your code in this cell - DO NOT DELETE THIS LINE) 
z = u+v

# %% [markdown]
# **Try this!**
#
# Complete the code below to plot all the three vectors (`u`, `v`, `z`) in the same figure, using `plt.arrow`.

# %%
# We will use the code snippet below to make a plot with the same aspect ratio for both axes
ax = plt.gca()
ax.set_aspect('equal')

# To define the limits in the x and y-directions
plt.xlim(0,8)
plt.ylim(0,8)
# Adding labels to the plot
plt.xlabel('x');
plt.ylabel('y');

# Plot all the three vectors using plt.arrow below
plt.arrow(0,0,u[0],u[1],length_includes_head=True, head_width=0.1)
plt.arrow(0,0,v[0],v[1],length_includes_head=True, head_width=0.1)
plt.arrow(0,0,z[0],z[1],length_includes_head=True, head_width=0.1)

# %% [markdown]
# Let's take a look at another plot. Instead of calling `plt.plot(x,y)`, we will do:

# %%
u = np.array([2,3])

plt.plot(u,'o')

# %% [markdown]
# Interesting? The plot above is actually the same as:

# %%
plt.plot(np.array([0,1]),u,'o')

# %% [markdown]
# In summary,
# ```python
# plt.plot(y)
# ```
# will plot y (with length $N$) using x as index array `0..N-1`, useful in cases when you want to plot values but don't have meaningful data for the x-axis.

# %% [markdown]
# This gives the possibility of plotting vectors with size $N>3$, where the vector will be interpreted as an array of $N$ values instead of as a point in $\mathbb{R}^N$.  You can see an example of this below.

# %% [markdown]
# #### Random vector

# %% [markdown]
# We can create a vector with N random entries (vector in $\mathbb{R}^N$)

# %%
yrand = np.random.rand(100)

print(yrand.shape)
print(yrand[10:20])
# Out:
# (100,)
# [1.72251361e-01 6.38659211e-01 2.88470347e-01 6.32551994e-04
#  3.20541397e-01 2.85281275e-01 7.37233955e-01 2.71944693e-01
#  4.55175792e-01 7.15952683e-01]

# %% [markdown]
# Passing `yrand` to `plt.plot()` will directly plot each entry:

# %%
plt.plot(yrand,'o-')    # 'o-' here specifies the points to be drawn with circles and a solid line. See https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.plot.html for more information
plt.ylabel('yrand')
# Out:
# Text(0, 0.5, 'yrand')

# %% [markdown]
# ## 3) Colors

# %% [markdown]
# In computer graphics, colors are commonly stored by mixing together certain amounts of red, blue, and green (RGB color space). We can thus define RGB colors as vectors in $\mathbb{R}^3$:

# %% [markdown]
# $$
# \begin{align*}
# {\bf red} &= \left(1, 0, 0\right) \\
# {\bf green} &= \left(0, 1, 0\right) \\
# {\bf blue} &= \left(0, 0, 1\right)
# \end{align*}
# $$

# %% [markdown]
# Which we can then store as numpy arrays:

# %%
red   = np.array([1,0,0])
green = np.array([0,1,0])
blue  = np.array([0,0,1])

# %% [markdown]
# We will use
# ```python
# plt.Circle( (x,y), radius , color=color_array )
# ```
# to create circles with different colors at positions (x,y)

# %%
radius = 0.2

# %%
ax = plt.gca()
ax.set_aspect('equal')
plt.xlim(0,2)
plt.xlabel('x')
plt.ylabel('y')

cred = plt.Circle((0.5,0.5), radius ,color=red)
ax.add_patch(cred)

cgreen = plt.Circle((1,0.5), radius ,color=green)
ax.add_patch(cgreen)

cblue = plt.Circle((1.5,0.5), radius ,color=blue)
ax.add_patch(cblue)

# %% [markdown]
# We will use linear combinations of the above vectors to obtain different color shades.
#
# First, write the color ${\bf c}  =  x \, {\bf red} $ where $x$ is a number between 0 and 1

# %% [markdown]
# **Check your answers!**
#
# Get the value of `x` provided in the main page of your PrairieLearn question, and define it as a variable.
# Then, define the variable `c`, the color defined above which is a shade of red, using the provided value for `x`:

# %%
#grade (enter your code in this cell - DO NOT DELETE THIS LINE) 
x = 0.84 # replace 0 with the value provided in the main page
# define c below
c = np.array([x,0,0])

# %% [markdown]
# We will plot a circle at position $(x,0.5)$ with color shade given by ${\bf c}  =  x \, {\bf red} $

# %%
ax = plt.gca(); ax.set_aspect('equal')
plt.xlim(0,1);plt.ylim(0.4,0.6); plt.xlabel('x'); plt.ylabel('y')

circ = plt.Circle((x,0.5), 0.04 ,color=c)
ax.add_patch(circ)

# %% [markdown]
# In the same figure, plot circles with colors ${\bf c}  =  x \, {\bf red} $ where $x$ varies from 0 to 1, with increment 0.1.

# %%
ax = plt.gca(); ax.set_aspect('equal')
plt.xlim(0,1);plt.ylim(0.4,0.6); plt.xlabel('x'); plt.ylabel('y')

for x in np.arange(0.,1.1,0.1):
    rs = x*red
    c = plt.Circle((x,0.5), 0.04 ,color=rs)
    ax.add_patch(c)

# %% [markdown]
# We will now write the color ${\bf c}  =  x {\bf u} + y {\bf v} $. For now, we assume that ${\bf u}$ is red and ${\bf v}$ is green. In the next code snippet, we plot circles with position $(x,y)$, radius 0.04, and color defined by  ${\bf c}$. It has a grid of $100$ circles ranging from $[0, 1]$ on the $x$ and $y$ axes.

# %%
ax = plt.gca(); ax.set_aspect('equal')
plt.xlim(0,1);plt.ylim(0,1); plt.xlabel('x',fontsize=20); plt.ylabel('y',fontsize=20)

u = red
v = green

points = np.arange(0.,1.1,0.1)

for x in points:
    for y in points:
        # This is the linear combination
        c = x*u + y*v
        circ = plt.Circle((x,y), 0.04, color=c)
        ax.add_patch(circ)

# %% [markdown]
# **Try this!**
#
# Complete the function `make_color_plot` below, so you can use the same code snippet, but with different choices of ${\bf u}$ and ${\bf v}$. The arguments should be the numpy arrays with the colors to be mixed.
#
# Add each color combination (`c`) to the list `colors`.
#
# Once you have the entire list, cast the `colors` list as a numpy array and return it at the end of the function. You can use `list.append()` to add elements to a list. See [here](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists) for more information.
#
# For grading purposes, we will be checking the resulting numpy arrays `colors`.

# %%
#grade (enter your code in this cell - DO NOT DELETE THIS LINE) 
def make_color_plot(u,v):

    ax = plt.gca(); ax.set_aspect('equal')
    plt.xlim(0,1);plt.ylim(0,1); plt.xlabel('x',fontsize=20); plt.ylabel('y',fontsize=20)

    colors = []
    
    points = np.arange(0.,1.1,0.1)
    # add your code here
    for x in points:
        for y in points:
            # This is the linear combination
            c = x*u + y*v
            circ = plt.Circle((x,y), 0.04, color=c)
            ax.add_patch(circ)
            colors.append(c)
        
    return np.array(colors)

# %% [markdown]
# Now plot the circles use your `make_color_plot` with different colors.

# %%
make_color_plot(green,red);

# %%
make_color_plot(red,blue);

# %% [markdown]
# We can define `purple = (red + blue)/2`.
#
# If we call `make_color_plot(blue,purple)` below **we get an error**. Why? (Hint: read the last line of the error message.)

# %%
purple = (red + blue)/2
make_color_plot(blue,purple);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-c69ff910fafc> in <module>
#       1 purple = (red + blue)/2
# ----> 2 make_color_plot(blue,purple);
#
# <ipython-input-90-cdf3789c8a71> in make_color_plot(u, v)
#      13             # This is the linear combination
#      14             c = x*u + y*v
# ---> 15             circ = plt.Circle((x,y), 0.04, color=c)
#      16             ax.add_patch(circ)
#      17             colors.append(c)
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/patches.py in __init__(self, xy, radius, **kwargs)
#    1528         %(Patch)s
#    1529         """
# -> 1530         Ellipse.__init__(self, xy, radius * 2, radius * 2, **kwargs)
#    1531         self.radius = radius
#    1532
#
# /opt/conda/lib/python3.8/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#    1402         %(Patch)s
# ...

# %% [markdown]
# The issue is that when making combinations of `red` and `purple`, we can produce array values **greater than 1**.
#
# The color values should be within the range $\left[0, 1\right]$. We can obtain that using [`np.clip`](https://numpy.org/doc/stable/reference/generated/numpy.clip.html) to force the values into a given range. For example, given the numpy array:

# %%
inter = np.array([0.3,0.4,3])

# %% [markdown]
# We can clip the interval to remain inside pre-defined edges:

# %%
np.clip(inter,0,1)
# Out:
# array([0.3, 0.4, 1. ])

# %% [markdown]
# **Check your answers!**
#
# Complete the `make_color_plot_clip()` function that ensures the color obtained by the linear combination satisfies the RGB requirements
#
# For this function, you need to put the computed color for each point in the list `colors`.
#
# Once you have the entire list, cast the `colors` list as a numpy array and return it at the end of the function. You can use `list.append()` to add elements to a list. See [here](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists) for more information.
#
# For grading purposes, we will be checking the resulting numpy arrays `colors`.

# %%
#grade (enter your code in this cell - DO NOT DELETE THIS LINE) 
def make_color_plot_clip(u,v):

    ax = plt.gca(); ax.set_aspect('equal')
    plt.xlim(0,1);plt.ylim(0,1); plt.xlabel('x',fontsize=20); plt.ylabel('y',fontsize=20)

    colors = [] # append computed colors to this list

    points = np.arange(0.,1.1,0.1)
    # add your code here
    for x in points:
        for y in points:
            # This is the linear combination
            c = x*u + y*v
            c = np.clip(c, 0, 1)
            circ = plt.Circle((x,y), 0.04, color=c)
            ax.add_patch(circ)
            colors.append(c)
    
    return np.array(colors)

# %% [markdown]
# You can check if the function is working properly for the given input:

# %%
make_color_plot_clip(blue,purple);

# %% [markdown]
# ## 4) Sounds

# %%
import scipy.io.wavfile as wav
import IPython.display as ipd

# %% [markdown]
# ### Create a music note

# %% [markdown]
# Sound data can be represented as a long vector, with each component storing the waveform amplitude at some point in time.
#
# Let's make the sound of the A5 note. (https://en.wikipedia.org/wiki/Piano_key_frequencies)

# %%
# We want to have the note played for 0.3 seconds
duration = 0.3
# Define the sampling rate, in hertz (seconds^-1)
DEFAULT_RATE = 44100
# The number of samples needed is
nsamples = int(DEFAULT_RATE*duration)
# The frequency of A5 is 880. 
w = 880

# %% [markdown]
# We need to create an array of time samples, starting from zero, finishing at `duration`, with `nsamples` points. We will use `np.linspace` for that:

# %%
t = np.linspace(0, duration, nsamples)

# %% [markdown]
# The sound function is:
#
# $f(t) = \sin(w \,2 \pi \,t)$
#
# Define the numpy array `f` corresponding to the points in `t`.
#
# Recall from section 1 that Numpy can perform many operations element-wise for you.

# %%
#grade (enter your code in this cell - DO NOT DELETE THIS LINE) 
import math

f = np.sin(w * 2 * math.pi * t)

# %% [markdown]
# Check the shape of `f`, does this make sense given the above parameters?

# %%
f.shape
# Out:
# (13230,)

# %% [markdown]
# Plot the sound given by `f`. Inspect a small region of the plot using [`plt.xlim(xlow,xhigh)`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.xlim.html)

# %%
plt.plot(f,'o-')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# Listen to the sound you created!

# %%
ipd.Audio(f,rate=DEFAULT_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Let's check some mixed sounds

# %% [markdown]
# #### Example 1:

# %%
# This is the rate:
sound1_rate = 32000
# This is the data:
sound1 = np.loadtxt('sound1.txt')

# %% [markdown]
# `sound1` is a numpy array. Check the shape:

# %%
sound1.shape
# Out:
# (245376,)

# %% [markdown]
# Plot the sound data:

# %%
plt.plot(sound1)

# %% [markdown]
# Play the sound:

# %%
ipd.Audio(sound1,rate=sound1_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The audio stored in `sound1` was obtaining by a linear combination of two different audios (voice + applause).
#
# **Try this!**
#
# Get the data from the applause by loading `applause.txt` as the variable `applause`.

# %%
applause = np.loadtxt('applause.txt')

# %% [markdown]
# **Check your answers!**
#
# Use your knowledge of linear combination to create an array with the data of the voice only. Store that as a variable `just_voice`.

# %%
#grade (enter your code in this cell - DO NOT DELETE THIS LINE) 
just_voice = sound1 - applause

# %% [markdown]
# Use `ipd.Audio` to check the resulting audio.

# %%
plt.plot(just_voice,'r')
ipd.Audio(just_voice,rate=sound1_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# We will plot a small range of the three different sounds: voice only, applause only and mixed. Observe the linear combination.

# %%
plt.plot(just_voice,'ro',label='voice')
plt.plot(applause,'bo',label='applause')
plt.plot(sound1,'go',label='mixed')
plt.legend()
plt.xlim(80000,80030)
plt.ylim(-10000,10000)
# Out:
# (-10000.0, 10000.0)

# %% [markdown]
# We can choose one of the points (time), and inspect the values of three arrays at this position. Verify the linear combination.

# %%
a=80005
print(just_voice[a],applause[a],sound1[a])
print(just_voice[a]+applause[a],sound1[a])
# Out:
# 30988801.0 4999.0 6199.0
# 30993800.0 6199.0

# %% [markdown]
# #### Example 2:

# %% [markdown]
# **Try this!**
#
# You have again two audio arrays stored in:
#
# - `sound2.txt`
#
# - `steps.txt`
#
# Load both files by creating the variables `sound2` and `steps`,  and plot the audio data.

# %%
sound2_rate = 44100

# %% [markdown]
# Listen the audio from `sound2.txt`. You will notice some "steps" in the background (which are stored in `steps`)

# %%
ipd.Audio(sound2,rate=sound2_rate)

# %% [markdown]
# **Try this!**
#
# Remove the `steps` from `sound2`, to keep the voice only. You will notice that the coefficient used for the linear combination was not the integer '1'. Can you find the scalar coefficient used to scale `steps` before adding it to the voice?
